# %%
import pandas as pd
import matplotlib as mpl

# %%
# 1) Pandas program to read the given csv file.

data = pd.read_csv('data/AfricaCupofNationsMatches.csv')

# %%
# 2) get the first 7 rows of your data frame.
data.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
# 3) select the ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and ‘AwayTeamGoals’ 
query = data[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]

print(query)
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %%
# 4) select the rows where Egypt appears.

# %%
# 5) count the number of rows and columns of your data frame.
data.shape
# Out:
# (622, 12)

# %%
# 6)  select the rows where the ‘Attendance’ is missing.
columns_headers = data.columns.values
data.loc[data['Attendance'].isna(), columns_headers]
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %%
# 7) select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.
between_3_4 = data.loc[(data['HomeTeamGoals'] >3 )&(data['HomeTeamGoals'] <=6),columns_headers]
print(between_3_4)
# Out:
#      Year                      Date   Time            HomeTeam  \
# 2    1957                  16-Feb-57    NaN             Egypt
# 3    1959                  22-May-59    NaN              Egypt
# 6    1962                  14-Jan-62    NaN          Ethiopia
# 9    1962                  21-Jan-62    NaN          Ethiopia
# 12   1963                  28-Nov-63    NaN          Ethiopia
# 13   1963                  24-Nov-63    NaN              Egypt
# 15   1963                  28-Nov-63    NaN             Sudan
# 18   1965                  12-Nov-65    NaN           Tunisia
# 20   1965                  19-Nov-65    NaN           Senegal
# 21   1965                  12-Nov-65    NaN             Ghana
# 23   1965                  19-Nov-65    NaN             Ghana
# 29   1968                  14-Jan-68    NaN           Algeria
# 39   1968                  19-Jan-68    NaN             Ghana
# 46   1970                  10-Feb-70    NaN       Ivory Coast
# ...

# %%
# 8) change the “AwayTeamGoals” in the 3rd row to 10.
data.at[2, 'AwayTeamGoals'] = 10
# data
print(data)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# 9) sort the DataFrame first by ‘HomeTeam’ in ascending order, then by ‘HomeTeamScores’ in descending order.
data.sort_values(by=['HomeTeam','HomeTeamGoals'], ascending=[True, False]).head(3)
# Out:
#      Year      Date  Time   HomeTeam  AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 205  1990   2-Mar-90   NaN  Algeria    Nigeria            5.0            1.0
# 29   1968  14-Jan-68   NaN  Algeria     Uganda            4.0            0.0
# 135  1980  16-Mar-80   NaN  Algeria     Guinea            3.0            2.0
#
#        Stage SpecialWinConditions                 Stadium          City  \
# 205  Group A                  NaN    Stade 5 Juillet 1962       Algiers
# 29   Group A                  NaN  Hailé Sélassié Stadium   Addis Ababa
# 135  Group B                  NaN         Liberty Stadium        Ibadan
#
#      Attendance
# 205     85000.0
# 29      25000.0
# 135     20000.0

# %%
# 10) get list from DataFrame column headers.
col_list_headers = data.columns.values
print(col_list_headers)
# Out:
# ['Year' 'Date ' 'Time ' 'HomeTeam' 'AwayTeam' 'HomeTeamGoals'
#  'AwayTeamGoals' 'Stage' 'SpecialWinConditions' 'Stadium' 'City'
#  'Attendance']

# %%
# # 11) append a column of your choice to your DataFrame.
# data['Sequence']
# data.columns.values

# %%
# 12) add 2 rows to your DataFrame.
row_one = [1962, '18-Jan-64', None, 'Ghana', 'Uganda', 2, 1, 'Semifinals', None, 'Namboole Stadium', 'Addis Ababa', 30000]

row_two = [1959, '18-Jan-64', None, 'Ghana', 'Uganda', 2, 1, 'Semifinals', None, 'Namboole Stadium', 'Kampala', 30000]
data.loc[len(data.index)] = row_one
display(data.tail(5))
# Out:
#      Year                      Date   Time   HomeTeam  AwayTeam  \
# 618  2019  14 July 2019 (2019-07-14)  18:00  Senegal    Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00  Algeria    Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00  Tunisia    Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00  Senegal    Algeria
# 622  1962                  18-Jan-64   None     Ghana    Uganda
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            2.0            1.0            Semifinals
#
#        SpecialWinConditions                      Stadium         City  \
# 618   win after extra time               30 June Stadium        Cairo
# 619                     NaN  Cairo International Stadium        Cairo
# ...

# %%
# 13) change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame.
# columns_headers = data.columns.values
data.loc[data['AwayTeam'].str.strip()=='Uganda']='China'
print(data.head(20))
# Out:
#      Year      Date   Time    HomeTeam       AwayTeam HomeTeamGoals  \
# 0    1957  10-Feb-57    NaN     Sudan           Egypt           1.0
# 1    1957  10-Feb-57    NaN  Ethiopia    South Africa           NaN
# 2    1957  16-Feb-57    NaN     Egypt        Ethiopia           4.0
# 3    1959  22-May-59    NaN      Egypt       Ethiopia           4.0
# 4    1959  25-May-59    NaN     Sudan        Ethiopia           1.0
# 5    1959  29-May-59    NaN      Egypt          Sudan           2.0
# 6    1962  14-Jan-62    NaN  Ethiopia         Tunisia           4.0
# 7   China      China  China      China          China         China
# 8   China      China  China      China          China         China
# 9    1962  21-Jan-62    NaN  Ethiopia           Egypt           4.0
# 10   1963  24-Nov-63    NaN     Ghana         Tunisia           1.0
# 11   1963  26-Nov-63    NaN     Ghana        Ethiopia           2.0
# 12   1963  28-Nov-63    NaN  Ethiopia         Tunisia           4.0
# ...

# %%
# 14) reset index in your DataFrame.
data = pd.read_csv('data/AfricaCupofNationsMatches.csv')
# data.head(3)
data.set_index(['Year','HomeTeamGoals'])
print(data.index)
data.reset_index(drop=False)
# Out:
# RangeIndex(start=0, stop=622, step=1)
#      index  Year                      Date   Time      HomeTeam  \
# 0        0  1957                  10-Feb-57    NaN       Sudan
# 1        1  1957                  10-Feb-57    NaN    Ethiopia
# 2        2  1957                  16-Feb-57    NaN       Egypt
# 3        3  1959                  22-May-59    NaN        Egypt
# 4        4  1959                  25-May-59    NaN       Sudan
# ..     ...   ...                        ...    ...          ...
# 617    617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar
# 618    618  2019  14 July 2019 (2019-07-14)  18:00     Senegal
# 619    619  2019  14 July 2019 (2019-07-14)  21:00     Algeria
# 620    620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia
# 621    621  2019  19 July 2019 (2019-07-19)  21:00     Senegal
#
#           AwayTeam  HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0            Egypt            1.0            2.0            Semifinals
# ...

# %%
df = pd.DataFrame({'name':['John', 'Joan','Edgar'],'age':[34,12,67], 'class':['p1','p2','p3']}, index=['a','b','c'])


print(df)
# df.set_index(['age','class'])
df.reset_index(drop=True)
# Out:
#     name  age class
# a   John   34    p1
# b   Joan   12    p2
# c  Edgar   67    p3
#     name  age class
# 0   John   34    p1
# 1   Joan   12    p2
# 2  Edgar   67    p3
