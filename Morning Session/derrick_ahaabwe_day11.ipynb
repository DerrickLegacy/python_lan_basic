# %%
# Machine Learning

# Types of machine learning Supervised learning
# Unsupervised Learning
# Reinforcement learning
# Data preprocessing 
# Data cleaning

# Steps
# Check for
# 1. Duplicates, wrong format, wrong data, empty cells, missing data
# Age 23,  230, 1.33, 1.44, 1.50, wrong format, 1/7/2024, 2/7/2024,  372024  , 4/7/2024, NaN, 6/7/2024
# Handling missing data, remove/delete, Imputation ( Mean, Median/Mode), forward/backward filling, kNN or Regression

# Explatory Data Analysis
# Steps
# 1. Descriptive statistics 
# Measure of Central Tendancy, Mean, Median, Mode,
# Measure of  Spread: range, variance, standard deviation, iterquartile range
# Skewness(left and right): understand the kind of data ie towards positive or negative, Kurtosis

# 2. Data Visualization, Histogram shows distribution of a single variable. ,  Box plots for identifying outliers,
# Scatter plot - examining relationships between two variables.
# Heatmaps - used for visualizing correlation matrics 

# Tools for data visualization
# Matplotlib, Line, bar, scatter and histogram
# Seaborn: has themes, colours, color palettes, looks more atrractive
# Plotly, Bokeh
# Feature Engineering
# Selection,Filter like chi-square, ANOVA,,
# Wrapper recursive features
# Embedded, Lasso regression
#CARGO personal use, data sets and solutions

# // Feature scaling and Normalization
# Normalization Rescale to a range, (Age, 20-28)
# Standard Deviation, transform std,

# Create new features, Polynomials, interaction
# Data Splitting
# Training and evaluation of a model
# Most common ratios, 20testing - 80training, 30, 70
# import Sckit-learn help to splite train_test_split
# Random state is used to shuffle data before splitting it into a training and test set. 

# Cross validation  - evaluate the performance of the data, multiple folds
# validation helps us know the performance of a model

# Types of cross validation are; train/test we can use K-Fold Cross Validation 
# Stratified k-Fold, Ensure our distribution of the target variable, particularly used in the imbalance datasets
# Cross validation helps in reducing variance in model performance estimates
# Provides a comprehensive evaluation of model performance 
# you should show the algorithm being used in your work.
# platform Esom for classes ....

# Supervised learning Algorithm
# 1. Regression, Linear or Polynomial 
# 2. Classification, (problems can be)
# Logistic regression, k-Nearest Neighbors(kNN), Support Vector Machine(SVM), Decision Trees and Random Forest

# Model Evaluation
# we have metrics 
# Metrics: Accuracy, Precision, Recall, F1-Score
# Confusion Matrix,
# AUC and ROC, Area Under the Curve, Receiver Operating characteristics Curve 
# Summary Supervised Learning
# Supervised learning deals with labeled data, and used for predict outcome/ output for new inputs, Common Task, are Classification and Regression
# examples are Linear regression, Random Forest

# Summary Unsupervised Learning
# it learns from data
# deals with unlabelled data, eg images of cats, dogs etc. find hidden patterns or structures in data, Common task Like, Clustering, Dimensionality, association Rule Learning

# Definition
# Supervised learning: learns from labelled data to predict outputs and outputs for new inputs
# Unsupervised learning: Learns from unlabelled data to identify patterns and structures within data.

# %%
import pandas as pd 
import seaborn as sn 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/heart.csv')

# Display the first few rows of the dataset.
df.head()
df.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 251   43    1   0       132   247    1        0      143      1      0.1
# 109   50    0   0       110   254    0        0      159      0      0.0
# 209   59    1   0       140   177    0        1      162      1      0.0
# 14    58    0   3       150   283    1        0      162      0      1.0
# 63    41    1   1       135   203    0        1      132      0      0.0
#
#      slope  ca  thal  target
# 251      1   4     3       0
# 109      2   0     2       1
# 209      2   1     3       0
# 14       2   0     2       1
# 63       1   0     1       1

# %%
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#Chech for wrong data 
print(df['oldpeak'].unique())
# Out:
# [2.3 3.5 1.4 0.8 0.6 0.4 1.3 0.  0.5 1.6 1.2 0.2 1.8 1.  2.6 1.5 3.  2.4
#  0.1 1.9 4.2 1.1 2.  0.7 0.3 0.9 3.6 3.1 3.2 2.5 2.2 2.8 3.4 6.2 4.  5.6
#  2.9 2.1 3.8 4.4]

# %%
# Explatory Data Analysis
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
mean = df.mean()
median = df.median()
range_ = df.max() - df.min()
variance = df.var()
std_dev = df.std()

# %%
#Interquartile Range (IQR):
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
#Skew and Kurtosis
skewness = df.skew()
kurtosis = df.kurt()

# %%
correlated_df = df
correlated_df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
#  2. Data Visualization, 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Correlation Visualization Using Heatmaps
    # 1 . Pearson correlation type
sns.heatmap(
    correlated_df.corr(), 
    annot=True, cmap='cividis', # 'viridis', 'plasma', 'inferno', 'magma', 'cividis', 'Blues', 'BuGn', 'BuPu', 'GnBu', 'Greens', 'Greys', 'Oranges', 'OrRd','PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu', 'Reds', 'YlGn','YlGnBu', 'YlOrBr', 'YlOrRd', 'cubehelix', 'Spectral'
)
# Out:
# <Axes: >

# %%
# 2. Kendall
correlated_df.corr(method ='kendall')
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.082272 -0.071577  0.201071  0.135062  0.094595
# sex      -0.082272  1.000000 -0.057955 -0.044438 -0.124104  0.045032
# cp       -0.071577 -0.057955  1.000000  0.027548 -0.069899  0.083862
# trestbps  0.201071 -0.044438  0.027548  1.000000  0.086474  0.127574
# chol      0.135062 -0.124104 -0.069899  0.086474  1.000000  0.015140
# fbs       0.094595  0.045032  0.083862  0.127574  0.015140  1.000000
# restecg  -0.109349 -0.048085  0.060839 -0.105147 -0.132664 -0.080996
# thalach  -0.280009 -0.032817  0.246160 -0.027760 -0.031437 -0.011749
# exang     0.074427  0.141664 -0.390708  0.044419  0.075044  0.025665
# oldpeak   0.193269  0.086437 -0.125081  0.109103  0.035176  0.024342
# slope    -0.147713 -0.024333  0.145796 -0.070360 -0.010039 -0.044546
# ca        0.273255  0.112199 -0.189400  0.070387  0.088549  0.126434
# thal      0.070722  0.244164 -0.188999  0.049028  0.066255 -0.006559
# ...

# %%
sn.heatmap(
    correlated_df.corr(method="kendall"), 
    cmap=sn.cubehelix_palette(as_cmap=True),
    annot=True, 
    fmt=".2f",
    annot_kws={"size": 8,"color":"black"},
    )
# Out:
# <Axes: >

# %%
# 3. Spearman
correlated_df.corr(method ='spearman')
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.099131 -0.087494  0.285617  0.195786  0.113978
# sex      -0.099131  1.000000 -0.062041 -0.052941 -0.151342  0.045032
# cp       -0.087494 -0.062041  1.000000  0.035413 -0.091721  0.089775
# trestbps  0.285617 -0.052941  0.035413  1.000000  0.126562  0.151984
# chol      0.195786 -0.151342 -0.091721  0.126562  1.000000  0.018463
# fbs       0.113978  0.045032  0.089775  0.151984  0.018463  1.000000
# restecg  -0.132769 -0.048389  0.065640 -0.125841 -0.161933 -0.081508
# thalach  -0.398052 -0.039868  0.324013 -0.040407 -0.046766 -0.014273
# exang     0.089679  0.141664 -0.418256  0.052918  0.091514  0.025665
# oldpeak   0.268291  0.100715 -0.161449  0.154267  0.045260  0.028363
# slope    -0.184048 -0.025010  0.159478 -0.086570 -0.012551 -0.045786
# ca        0.340955  0.119368 -0.216006  0.090140  0.111981  0.134513
# thal      0.087254  0.250821 -0.207840  0.059673  0.083628 -0.006737
# ...

# %%
sn.heatmap(
    correlated_df.corr(method="spearman"), 
    cmap="Spectral",
    annot=True, 
    fmt=".2f",
    annot_kws={"size": 8,"color":"black"},
    )
# Out:
# <Axes: >

# %% [markdown]
# # Machine Learning
#      Splitting Data
#          1. Train Data (80%)
#             a) Identify dependent, y
#             b) Identify Independent, x
#          2. Test Data (20%)

# %% [markdown]
# **Trainining**
# * a) Extract the independent variables
# * b) Extract the dependent variables too.
# * c) Identifying and handling the missing values
#     * Deleting a particular row
#     * Calculating the mean
# * d) Encoding the categorical data (since we are dealing with numbers only we need to encode this data to numbers)
#     * We can use LabelEncoder() class from the sci-kit learn library

# %%
# Dependent and Independent Variables
y = df['target']  # Dependent variable
x = df.drop(columns=['target'])  # Independent variables

x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
#Splitting Data
from sklearn.model_selection import train_test_split

x_train, x_test, y_train,y_test = train_test_split(x,y, test_size=.2,random_state=0)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 74    43    0   2       122   213    0        1      165      0      0.2
# 153   66    0   2       146   278    0        0      152      0      0.0
# 64    58    1   2       140   211    1        0      165      0      0.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 287   57    1   1       154   232    0        0      164      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 251   43    1   0       132   247    1        0      143      1      0.1
# 192   54    1   0       120   188    0        1      113      0      1.4
# 117   56    1   3       120   193    0        0      162      0      1.9
# 47    47    1   2       138   257    0        0      156      0      0.0
# 172   58    1   1       120   284    0        0      160      0      1.8
#
#      slope  ca  thal
# 74       1   0     2
# 153      1   1     2
# 64       2   0     2
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() # We can pass the range too i.e scaler = MinMaxScaler(feature_range=(0,3))

#  Scaling the traing and test data
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)
# Out:
# array([[0.29166667, 0.        , 0.66666667, ..., 0.5       , 0.        ,
#         0.66666667],
#        [0.77083333, 0.        , 0.66666667, ..., 0.5       , 0.25      ,
#         0.66666667],
#        [0.60416667, 1.        , 0.66666667, ..., 1.        , 0.        ,
#         0.66666667],
#        ...,
#        [0.5625    , 1.        , 1.        , ..., 0.5       , 0.        ,
#         1.        ],
#        [0.375     , 1.        , 0.66666667, ..., 1.        , 0.        ,
#         0.66666667],
#        [0.60416667, 1.        , 0.33333333, ..., 0.5       , 0.        ,
#         0.66666667]])

# %%
# # Histogram of all features
# df.hist(figsize=(12, 10))
# plt.suptitle('Histograms of Features', fontsize=16)
# plt.show()

# # Pairplot to see relationships between features
# sns.pairplot(df, hue='target')
# plt.suptitle('Pair Plot', fontsize=16)
# plt.show()

# # Box plots to see distributions
# plt.figure(figsize=(12, 6))
# sns.boxplot(data=df)
# plt.xticks(rotation=90)
# plt.title('Box Plots of Features')
# plt.show()

# # Correlation heatmap
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# plt.title('Correlation Heatmap')
# plt.show()
# Out:
# /home/derrick-legacy256/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/derrick-legacy256/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/derrick-legacy256/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
